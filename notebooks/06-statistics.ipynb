# %% [markdown]
# Before we start, run the code cell below for a nicer layout.

# %%
# %%html
# <style>
# h1 { margin-top: 3em !important; }
# h2 { margin-top: 2em !important; }
# h3 { margin-top: 1em !important; }
# #notebook-container {
#     width: 50% !important;
#     min-width: 800px;
# }
# </style>
# Out:
# <style>
# h1 { margin-top: 3em !important; }
# h2 { margin-top: 2em !important; }
# h3 { margin-top: 1em !important; }
# #notebook-container {
#     width: 50% !important;
#     min-width: 800px;
# }
# </style>

# %% [markdown]
# <h1>The shark dataset: statistics</h1>
#
# We will used the cleaned version of the shark dataset that you produced in week four, please make sure that this notebook is located in the same folder as `04-real-data.ipynb`. Make sure that the following cell has a sensible output.

# %%
import pandas as pd
import matplotlib.pyplot as plt

sharks = pd.read_csv('04-resources/sharks-cleaned.csv', index_col=0)
sharks.head(50)
# Out:
#      Year       Country                 Activity  Age  \
# 0    2018           USA                 Paddling   57
# 6    2018        BRAZIL                 Swimming   18
# 7    2018           USA                  Fishing   52
# 8    2018           USA                  Walking   15
# 10   2018     AUSTRALIA           Feeding sharks   32
# 13   2018       ENGLAND                  Fishing   21
# 14   2018     AUSTRALIA           Feeding sharks   34
# 18   2018    COSTA RICA             Scuba diving   30
# 21   2018     AUSTRALIA                  Surfing   60
# 23   2018      MALDIVES                  Fishing   32
# 24   2018  SOUTH AFRICA            Paddle-skiing   33
# 25   2018           USA            Body boarding   29
# 26   2018      THAILAND                 Swimming   54
# 31   2018        BRAZIL                  Fishing   56
# 33   2018       BAHAMAS                 Swimming   12
# 34   2018  SOUTH AFRICA                  Surfing   19
# 35   2018           USA  Stand-Up Paddleboarding   25
# 36   2018     AUSTRALIA                   Wading   10
# 37   2018     AUSTRALIA                 Swimming   69
# 38   2018     AUSTRALIA                  Surfing   18
# 39   2018  SOUTH AFRICA             Scuba Diving   38
# 40   2018     AUSTRALIA                 Swimming   55
# 42   2018     AUSTRALIA                  Walking   35
# 44   2018        BRAZIL            Cleaning fish   46
# 45   2018       ECUADOR               Snorkeling   45
# 46   2018     AUSTRALIA             Spearfishing   14
# 50   2018     AUSTRALIA              Free diving   28
# 51   2018        BRAZIL                  Surfing   20
# 53   2017           USA                  Surfing   54
# 55   2017      MALAYSIA         Fishing / Wading   24
# 56   2017       BAHAMAS               Snorkeling   25
# 57   2017    COSTA RICA             Scuba Diving   26
# 58   2017    COSTA RICA             Scuba diving   49
# 60   2017           USA             Spearfishing   25
# 63   2017     AUSTRALIA                  Surfing   25
# 64   2017          CUBA            Night bathing   22
# 65   2017     AUSTRALIA               Snorkeling    7
# 66   2017     AUSTRALIA                  Surfing   31
# 71   2017     AUSTRALIA       Kayaking / Fishing   15
# 74   2017           USA                  Surfing   54
# 75   2017           USA               Snorkeling   40
# 76   2017  SOUTH AFRICA             Scuba Diving   31
# 79   2017           USA                  Surfing   33
# 82   2017         SPAIN             Body surfing   13
# 87   2017           USA                  Surfing   18
# 89   2017     AUSTRALIA                  Surfing   35
# 96   2017     AUSTRALIA                  Surfing   37
# 98   2017         SPAIN                 Swimming   11
# 100  2017           USA                      SUP   69
# 102  2017           USA                 Swimming   13
#
#                                           Species  Sex  \
# 0                                      White shark   F
# 6                                      Tiger shark   M
# 7                                  Lemon shark, 3'   M
# 8                                   Bull shark, 6'   M
# 10                                 Grey reef shark   M
# 13                                Invalid incident   M
# 14                           Tawny nurse shark, 2m   F
# 18                                     Tiger shark   M
# 21                                       3 m shark   M
# 23                                     Tiger shark   M
# 24                              White shark, 2.5 m   M
# 25                                        6' shark   M
# 26                             Juvenile bull shark   M
# 31                 Shark involvement not confirmed   M
# 33                                      Bull shark   M
# 34                                     White shark   M
# 35                                Tiger shark, 12'   M
# 36                                 Wobbegong shark   M
# 37                                     3.5 m shark   M
# 38                                     1.8 m shark   M
# 39                                  Blacktip shark   M
# 40             Juvenile white shark,  2.7 to 3.2 m   F
# 42                                 Bull shark, 2 m   M
# 44   Injury believed caused by an eel, not a shark   F
# 45                                Galapagos shark?   M
# 46                                        2m shark   M
# 50                              White shark, 3.5 m   M
# 51                                     small shark   M
# 53                                     Tiger shark   F
# 55                            Juvenile nurse shark   M
# 56                                 Nurse shark. 5'   F
# 57                             Tiger shark, female   M
# 58                             Tiger shark, female   F
# 60                              White shark, 4.6 m   M
# 63                                       2 m shark   M
# 64                                     Tiger shark   M
# 65                              Cookiecutter shark   M
# 66                            Wobbegong shark, 1 m   M
# 71                              White shark, 4.5 m   F
# 74                       Tiger shark, 8 to 10 feet   M
# 75                                        8' shark   F
# 76             Death may have been due to drowning   M
# 79                                    Questionable   M
# 82                                Porbeagle, 1.5 m   M
# 87                                  5' to 6' shark   M
# 89                         White shark, 3 to 3.5m    M
# 96                                White shark, 3 m   M
# 98                  Shark involvement questionable   F
# 100                          White shark, 5' to 7'   M
# 102             Possibly a juvenile blacktip shark   M
#
#                                            Species
# 0                                      White shark
# 6                                      Tiger shark
# 7                                  Lemon shark, 3'
# 8                                   Bull shark, 6'
# 10                                 Grey reef shark
# 13                                Invalid incident
# 14                           Tawny nurse shark, 2m
# 18                                     Tiger shark
# 21                                       3 m shark
# 23                                     Tiger shark
# 24                              White shark, 2.5 m
# 25                                        6' shark
# 26                             Juvenile bull shark
# 31                 Shark involvement not confirmed
# 33                                      Bull shark
# 34                                     White shark
# 35                                Tiger shark, 12'
# 36                                 Wobbegong shark
# 37                                     3.5 m shark
# 38                                     1.8 m shark
# 39                                  Blacktip shark
# 40             Juvenile white shark,  2.7 to 3.2 m
# 42                                 Bull shark, 2 m
# 44   Injury believed caused by an eel, not a shark
# 45                                Galapagos shark?
# 46                                        2m shark
# 50                              White shark, 3.5 m
# 51                                     small shark
# 53                                     Tiger shark
# 55                            Juvenile nurse shark
# 56                                 Nurse shark. 5'
# 57                             Tiger shark, female
# 58                             Tiger shark, female
# 60                              White shark, 4.6 m
# 63                                       2 m shark
# 64                                     Tiger shark
# 65                              Cookiecutter shark
# 66                            Wobbegong shark, 1 m
# 71                              White shark, 4.5 m
# 74                       Tiger shark, 8 to 10 feet
# 75                                        8' shark
# 76             Death may have been due to drowning
# 79                                    Questionable
# 82                                Porbeagle, 1.5 m
# 87                                  5' to 6' shark
# 89                         White shark, 3 to 3.5m
# 96                                White shark, 3 m
# 98                  Shark involvement questionable
# 100                          White shark, 5' to 7'
# 102             Possibly a juvenile blacktip shark

# %% [markdown]
# Our goal is to explore the dataset, to see whether there are interesting or surprising facts to be found. Our main tool today will be <i>plots</i> for which we will use the `matplotlib` library.
# All five tasks have the following form: I provide you with a plot generated from the shark attack data and your task is to use `pandas` and `matplotlib` to create a similar plot.
#
# I suggest that you proceed as follows (but feel free to try your own approach!):
#
# <ol>
#     <li> Find out what data is shown in the plot and how you can obtain that data from the shark dataframe (just output it as a first step!)
#     <li> Find out how to produce a plot of the shown type using `matplotlib`. Produce a small test plot with mock data.
#     <li> Plot your data
#     <li> Adjust the plot's presentation to match the ones I provided,
#          you will have to research that online.
# </ol>

# %% [markdown]
# <h2>Attacks per year</h2>
#
# The following chart gives us an overview of how shark attacks
# (or shark attack <i>registration</i>) developed over time.
#
# <img src="06-resources/attacks_per_year.svg" />
#
# Hint: you will have to sum up the total number of attacks per year.
# The `.value_counts()` method of pandas dataframes comes in handy for that.

# %%
import pandas as pd
import matplotlib.pyplot as plt

sharks_year_counts = sharks['Year'].value_counts().sort_index()

y = sharks_year_counts.values
x = sharks_year_counts.index
fig, ax = plt.subplots()
ax.plot(x, y)
plt.xlabel('Year')
plt.ylabel('Shark attacks')
plt.show()

# %%
ind = (sharks['Country']=='USA')
sharks[ind]
# Out:
#       Year Country                                           Activity  Age  \
# 0     2018     USA                                           Paddling   57
# 7     2018     USA                                            Fishing   52
# 8     2018     USA                                            Walking   15
# 25    2018     USA                                      Body boarding   29
# 35    2018     USA                            Stand-Up Paddleboarding   25
# 53    2017     USA                                            Surfing   54
# 60    2017     USA                                       Spearfishing   25
# 74    2017     USA                                            Surfing   54
# 75    2017     USA                                         Snorkeling   40
# 79    2017     USA                                            Surfing   33
# 87    2017     USA                                            Surfing   18
# 100   2017     USA                                                SUP   69
# 102   2017     USA                                           Swimming   13
# 104   2017     USA                                            Fishing   34
# 107   2017     USA                                           Swimming   10
# 115   2017     USA                                           Swimming    8
# 116   2017     USA                                           Kayaking   40
# 117   2017     USA                                                SUP   50
# 121   2017     USA                                           Swimming   46
# 128   2017     USA                                           Swimming   14
# 139   2017     USA                                   Touching a shark   20
# 145   2017     USA                                            Surfing   18
# 156   2017     USA                                            Surfing   28
# 166   2017     USA                                           Swimming   17
# 195   2016     USA                                            Surfing   19
# 199   2016     USA                                           Floating   58
# 203   2016     USA                                            Surfing   36
# 220   2016     USA                                           Swimming   51
# 225   2016     USA                                       Spearfishing   22
# 227   2016     USA                                            Surfing   25
# ...    ...     ...                                                ...  ...
# 4461  1950     USA                      Body surfing / treading water   31
# 4469  1950     USA                                           Swimming   11
# 4471  1950     USA  Goggle-diving for seaweeds, but standing in water   21
# 4472  1950     USA                                          Swimming    16
# 4510  1949     USA                                            Fishing   16
# 4555  1948     USA                             Underwater photography   48
# 4570  1947     USA                                           Swimming   20
# 4571  1947     USA                                            Fishing   46
# 4646  1944     USA                                            Bathing   15
# 4743  1941     USA                              Fishing from 32' boat   43
# 4746  1941     USA                                            Fishing   53
# 4874  1936     USA                              Swimming crawl stroke   16
# 4900  1935     USA                       fishing boat exploded & sank   23
# 4901  1935     USA                       fishing boat exploded & sank   53
# 4904  1935     USA        Fishing for bluefish, shark leapt into dory   31
# 4961  1933     USA                             Sitting in 3' of water   15
# 4968  1933     USA                                           Swimming   24
# 4987  1932     USA                                            Fishing   32
# 5004  1931     USA                                          Swimming    20
# 5041  1930     USA                                           Swimming   21
# 5148  1926     USA             Swimming with dog near canning factory   15
# 5223  1922     USA                                           Floating   18
# 5251  1920     USA                                          Swimming    30
# 5304  1916     USA                                           Swimming   12
# 5305  1916     USA         Swimming (recovering remains of Stilwell)    24
# 5311  1916     USA                                           Swimming   24
# 5422  1909     USA  Reported swept away by waves while gathering o...   19
# 5571  1899     USA                                           Swimming   15
# 5598  1898     USA                                  Fishing (Seining)   15
# 5806  1881     USA                                            Bathing   18
#
#                                                Species  Sex  \
# 0                                           White shark   F
# 7                                       Lemon shark, 3'   M
# 8                                        Bull shark, 6'   M
# 25                                             6' shark   M
# 35                                     Tiger shark, 12'   M
# 53                                          Tiger shark   F
# 60                                   White shark, 4.6 m   M
# 74                            Tiger shark, 8 to 10 feet   M
# 75                                             8' shark   F
# 79                                         Questionable   M
# 87                                       5' to 6' shark   M
# 100                               White shark, 5' to 7'   M
# 102                  Possibly a juvenile blacktip shark   M
# 104                                            4' shark   M
# 107                                       A small shark   M
# 115                     Shark involvement not confirmed   F
# 116                             White shark, 11' to 13'   M
# 117                              White shark, 8' to 10'   M
# 121                                Bull shark, 4' to 5'   M
# 128                                Bull shark, 4' to 5'   F
# 139                                            3' shark   F
# 145                   Shark involvement highly doubtful   F
# 156                                    Tiger shark, 12'   M
# 166                                Bull shark, 5' to 7'   F
# 195                     Shark involvement not confirmed   M
# 199                                         Tiger shark   F
# 203                                      6' to 8' shark   M
# 220                                    Tiger shark, 10'   F
# 225                              White shark, 8' to 10'   M
# 227                                      Bull shark, 6'   M
# ...                                                 ...  ..
# 4461                                        White shark   M
# 4469                                   Hammerhead shark   M
# 4471                                 0.7 m [2.5'] shark   M
# 4472                                       "sand shark"   M
# 4510                              Bonita sharkk, 200-lb   M
# 4555                                        Nurse shark   M
# 4570                                 Possibly C. leucas   M
# 4571                                      a small shark   M
# 4646         1.8 m [6'] blacktip shark or spinner shark   F
# 4743                                   2.1 m [7'] shark   M
# 4746          Mako shark (aka bonito shark) 1.2 m [4']    M
# 4874        White shark (identified by Dr. Hugh Smith)    M
# 4900                                            Invalid   M
# 4901                                            Invalid   M
# 4904                                  4.6 m [15'] shark   M
# 4961  Thought to involve a 2.4 m [8'] lemon shark; t...   M
# 4968               Possibly a bull shark or tiger shark   M
# 4987                                 250-lb "dog shark"   M
# 5004  Hammerhead shark, 2.4 m [8'], according to lif...   F
# 5041                                        Tiger shark   M
# 5148          1.5 m [5'] white shark or sevengill shark   M
# 5223                                   1.8 m [6'] shark   F
# 5251                                       Questionable   M
# 5304                 Said to involve a 2.7 m [9'] shark   M
# 5305                                    3 m [10'] shark   M
# 5311      Thought to involve a 2.6 m [8.5'] white shark   M
# 5422                                       Questionable   F
# 5571                                    3 m [10'] shark   M
# 5598                                        White shark   M
# 5806       Shark involvement prior to death unconfirmed   M
#
#                                                 Species
# 0                                           White shark
# 7                                       Lemon shark, 3'
# 8                                        Bull shark, 6'
# 25                                             6' shark
# 35                                     Tiger shark, 12'
# 53                                          Tiger shark
# 60                                   White shark, 4.6 m
# 74                            Tiger shark, 8 to 10 feet
# 75                                             8' shark
# 79                                         Questionable
# 87                                       5' to 6' shark
# 100                               White shark, 5' to 7'
# 102                  Possibly a juvenile blacktip shark
# 104                                            4' shark
# 107                                       A small shark
# 115                     Shark involvement not confirmed
# 116                             White shark, 11' to 13'
# 117                              White shark, 8' to 10'
# 121                                Bull shark, 4' to 5'
# 128                                Bull shark, 4' to 5'
# 139                                            3' shark
# 145                   Shark involvement highly doubtful
# 156                                    Tiger shark, 12'
# 166                                Bull shark, 5' to 7'
# 195                     Shark involvement not confirmed
# 199                                         Tiger shark
# 203                                      6' to 8' shark
# 220                                    Tiger shark, 10'
# 225                              White shark, 8' to 10'
# 227                                      Bull shark, 6'
# ...                                                 ...
# 4461                                        White shark
# 4469                                   Hammerhead shark
# 4471                                 0.7 m [2.5'] shark
# 4472                                       "sand shark"
# 4510                              Bonita sharkk, 200-lb
# 4555                                        Nurse shark
# 4570                                 Possibly C. leucas
# 4571                                      a small shark
# 4646         1.8 m [6'] blacktip shark or spinner shark
# 4743                                   2.1 m [7'] shark
# 4746          Mako shark (aka bonito shark) 1.2 m [4']
# 4874        White shark (identified by Dr. Hugh Smith)
# 4900                                            Invalid
# 4901                                            Invalid
# 4904                                  4.6 m [15'] shark
# 4961  Thought to involve a 2.4 m [8'] lemon shark; t...
# 4968               Possibly a bull shark or tiger shark
# 4987                                 250-lb "dog shark"
# 5004  Hammerhead shark, 2.4 m [8'], according to lif...
# 5041                                        Tiger shark
# 5148          1.5 m [5'] white shark or sevengill shark
# 5223                                   1.8 m [6'] shark
# 5251                                       Questionable
# 5304                 Said to involve a 2.7 m [9'] shark
# 5305                                    3 m [10'] shark
# 5311      Thought to involve a 2.6 m [8.5'] white shark
# 5422                                       Questionable
# 5571                                    3 m [10'] shark
# 5598                                        White shark
# 5806       Shark involvement prior to death unconfirmed
#
# [900 rows x 7 columns]

# %% [markdown]
# <h2>Attacks by country</h2>
#
# The following plots shows the five countries with the largest number of attacks.
#
# <img src="06-resources/attacks_by_country.svg" />
#
# Hint: This type of plot is called a &lsquo;bar chart&rsquo;

# %%
sharks_country_counts = sharks['Country'].value_counts().head(5)
print(sharks_country_counts.head(5))

import matplotlib.pyplot as plt
import numpy as np
 
x = sharks_country_counts.index
y = sharks_country_counts.values

 
plt.barh(x, y)
plt.ylabel('Country')
plt.title('Registered Shark Attacks by Country')
plt.xlabel('Total Shark Attacks')

plt.show()
# Out:
# USA             900
# AUSTRALIA       470
# SOUTH AFRICA    266
# BAHAMAS          48
# NEW ZEALAND      34
# Name: Country, dtype: int64

# %% [markdown]
# <h2>Shark attacks over time: top three countries</h2>
#
# In the following plot we see the shark attacks over time again, but this time separated by country. Only the top three countries are plotted to keep it readable.
#
# <img src="06-resources/attacks_per_year_top.svg" />

# %%
import pandas as pd
import matplotlib.pyplot as plt

sharks_year_counts = sharks['Year'].value_counts().sort_index()
sharks_country_year = sharks[['Year', 'Country']]
sharks_country_counts = sharks_country_year['Country'].value_counts().head(3)

y = sharks_year_counts.values
x = sharks_year_counts.index
fig, ax = plt.subplots()
ax.plot(x, y)
plt.xlabel('Year')
plt.ylabel('Shark attacks')
plt.show()

# %%
sharks_country_year = sharks[['Year', 'Country']]
sharks_country_counts = sharks_country_year['Country'].value_counts().head(3)

ind = (['Country']=='USA')
#sharks_country_year_counts[ind]
#for i in sharks_country_counts:
print(sharks_country_counts)
#sharks_country_counts[ind]
# Out:
# USA             900
# AUSTRALIA       470
# SOUTH AFRICA    266
# Name: Country, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(sharks_country_counts.index, sharks_country_counts.values, label='label here')
plt.plot(sharks_year_counts.values, sharks_year_counts.index, label='label here')
plt.title('title')
plt.ylabel('ylabel')
plt.xlabel('xlabel')
plt.legend()
plt.show()

# %% [markdown]
# <h2>Age distribution by country</h2>
#
# The following plots gives us an overview of the age distribution of
# shark attack victims, separated by country. Only the top five countries are shown.
# <img src="06-resources/age_boxplot_country.svg" />
#
# Hint: As we discussed in class, this type of plot is called a box plot.

# %%
sharks_country_age = sharks[['Age', 'Country']]
sharks_country_counts = sharks_country_age['Country'].value().head(3)
print(sharks_country_counts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5d2f1a304553> in <module>()
#       1 sharks_country_age = sharks[['Age', 'Country']]
# ----> 2 sharks_country_counts = sharks_country_age['Country'].value().head(3)
#       3 print(sharks_country_counts)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = axes[0].boxplot(all_data,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels)  # will be used to label x-ticks
axes[0].set_title('Rectangular box plot')

# notch shape box plot
bplot2 = axes[1].boxplot(all_data,
                         notch=True,  # notch shape
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels)  # will be used to label x-ticks
axes[1].set_title('Notched box plot')

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %% [markdown]
# <h2>Age distribution by activity</h2>
#
# This plot shows the age distribution as well, but this time separated
# by activity. Only the top ten activities are shown.
# <img src="06-resources/age_boxplot_activity.svg" />
